# %%
from ann_system import ann_system
# Out:
# 2024-10-30 19:21:47.807322: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
param_dict = {
    'ttf-the': {
        'batch_size': 8,
        'lr' : 0.0038336791635842195,
        'units': 1,
        'lags': 5
    },
    'ttf-nbp': {
        'batch_size': 1,
        'lr' : 0.0038336791635842195,
        'units': 1,
        'lags': 6
    },
    'the-nbp': {
        'batch_size': 1,
        'lr' : 0.003319584493448066,
        'units': 2,
        'lags': 5
    }
}

# %%
validation_size = 250
test_size = 250
window_size = 5


pairs = ['ttf-the', 'ttf-nbp', 'the-nbp']

for pair in pairs:
    hub1_name, hub2_name = pair.split('-')
    print(f'Processing {hub1_name} and {hub2_name}')
    ann = ann_system(hub1_name, hub2_name, validation_size, test_size, window_size, param_dict[pair], verbose=True, save=True)
# Out:
# Processing ttf and the
# Epoch 1/25
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 51.2021
# Epoch 2/25
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27.1469
# Epoch 3/25
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3535
# Epoch 4/25
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.2225
# Epoch 5/25
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 6.1686
# Epoch 6/25
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 6.1615
# Epoch 7/25
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 834us/step - loss: 6.1459
# Epoch 8/25
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 6.1526
# Epoch 9/25
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.1688
# Epoch 10/25
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.1787
# Epoch 11/25
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.1705
# Epoch 12/25
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - loss: 6.1794
# Epoch 13/25
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.2446
# Epoch 14/25
# ...
