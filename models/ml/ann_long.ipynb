# %%
from ann_long import ann_system_rolling
# Out:
# 2024-11-11 12:19:15.444937: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import pandas as pd

# %%
param_dict = {
    'ttf-the': {
        'lr' : 0.0034989953431570587,
        'units': 2,
        'lags': 5
    },
    'ttf-nbp': {
        'lr' : 0.002011660009751183,
        'units': 2,
        'lags': 6
    },
    'the-nbp': {
        'lr' : 0.0020055959168877725,
        'units': 2,
        'lags': 5
    }
}
#lr = 0.0034989953431570587 # TTF-THE
#lr = 0.002011660009751183 # TTF-NBP
#lr = 0.0020055959168877725 # THE-NBP

# %%
validation_size = 250
test_size = 250
window_size = 5

# %%
from joblib import Parallel, delayed

# Define parameters for validation, test, and window sizes
validation_size = 250
test_size = 250
window_size = 5

# List of hub pairs and parameter dictionary
pairs = ['ttf-the', 'ttf-nbp', 'the-nbp']

# Define the processing function
def process_pair(pair):
    hub1_name, hub2_name = pair.split('-')
    print(f'Processing {hub1_name} and {hub2_name}')
    params = param_dict[pair]
    ann = ann_system_rolling(hub1_name, hub2_name, validation_size, test_size, window_size, params, verbose=True, save=True)
    return ann

# Run the function in parallel for each pair
if __name__ == "__main__":
    results = Parallel(n_jobs=3)(delayed(process_pair)(pair) for pair in pairs)
# Out:
# 2024-11-11 12:19:33.811610: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-11 12:19:33.811623: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-11 12:19:33.812055: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Processing ttf and nbp
# Processing ttf and the
# ...
